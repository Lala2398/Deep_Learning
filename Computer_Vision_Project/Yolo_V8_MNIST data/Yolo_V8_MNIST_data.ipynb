# %% [markdown]
# Data : https://github.com/zalandoresearch/fashion-mnist

# %%
#1. Mount Google Drive

#try:
from google.colab import drive

drive.mount('/content/gdrive')

#except Exception as e:
  #print("Failed to mount Google Drive:,e")
# Out:
# Mounted at /content/gdrive

# %%
## Download and unzip data (with error handling)

# !scp '/content/gdrive/My Drive/data/data.zip' '/content/data.zip'

# !unzip '/content/data.zip' -d '/content/'
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: /content/data/train/Trouser/19004.png
#  extracting: /content/data/train/Trouser/19009.png
#  extracting: /content/data/train/Trouser/1901.png
#  extracting: /content/data/train/Trouser/19020.png
#  extracting: /content/data/train/Trouser/19022.png
#  extracting: /content/data/train/Trouser/19029.png
#  extracting: /content/data/train/Trouser/19031.png
#  extracting: /content/data/train/Trouser/19034.png
#  extracting: /content/data/train/Trouser/19039.png
#  extracting: /content/data/train/Trouser/19045.png
#  extracting: /content/data/train/Trouser/19053.png
#  extracting: /content/data/train/Trouser/19058.png
#  extracting: /content/data/train/Trouser/19059.png
#  extracting: /content/data/train/Trouser/19061.png
#  extracting: /content/data/train/Trouser/19064.png
#  extracting: /content/data/train/Trouser/19071.png
#  extracting: /content/data/train/Trouser/19095.png
# ...

# %%
# Install Ultralytics for computer vision tasks

"""Reasons to use Ultralytics:

Speed and Accuracy: Ultralytics offers state-of-the-art performance in object detection, image segmentation, and classification tasks (https://docs.ultralytics.com/).

Ease of Use:It provides a user-friendly API and intuitive code structure, making it easier to implement and customize computer vision models (https://docs.ultralytics.com/).

Open-Source:Ultralytics is open-source under the permissive BSD-3 license, allowing for free usage and modification,
which fosters collaboration and community support (https://github.com/ultralytics/ultralytics).

End-to-End Platform (Optional):Ultralytics HUB offers an optional no-code platform for training and deploying models,
simplifying the process for those less familiar with deep learning frameworks (https://docs.ultralytics.com/)."""




# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 749.1/749.1 kB 16.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 65.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 61.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 76.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 11.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 7.1 MB/s eta 0:00:00
# ...

# %%
#!pip install git+https://github.com/ultralytics/ultralytics.git@main
# Out:
# ...
#   Cloning https://github.com/ultralytics/ultralytics.git (to revision main) to /tmp/pip-req-build-j3rgbbii
#   Running command git clone --filter=blob:none --quiet https://github.com/ultralytics/ultralytics.git /tmp/pip-req-build-j3rgbbii
#   Resolved https://github.com/ultralytics/ultralytics.git to commit 3208eb72ef277b0b825306a84df6c460a8406647
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...

# %%
#!pip install git+https://github.com/pytorch/torchdynamo@main
# Out:
# ...
#   Cloning https://github.com/pytorch/torchdynamo (to revision main) to /tmp/pip-req-build-fxic07i6
#   Running command git clone --filter=blob:none --quiet https://github.com/pytorch/torchdynamo /tmp/pip-req-build-fxic07i6
#   Resolved https://github.com/pytorch/torchdynamo to commit d36a5e74b6141d119a60d8e79973f4e63b605013
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached dill-0.3.8-py3-none-any.whl (116 kB)
# ...
#   Created wheel for torchdynamo: filename=torchdynamo-1.14.0.dev0-py3-none-any.whl size=3826 sha256=31766e485c3eeda1ceec60db6a8090df0847da474e0e4df2d074f7c70f2986db
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ctsirpmu/wheels/4f/8b/e5/ce645aa7e4d1b12f68225592f8a8eccf19f789a71358e121eb
# Successfully built torchdynamo
# ...

# %%
### 4. Train model ###

import os

from ultralytics import YOLO


# Load a model
model = YOLO("yolov8n-cls.pt")  # load a pretained model

# Use the model
results = model.train(data='/content/data/', epochs=5)  # train the model
# Out:
# ...
# 100%|██████████| 5.30M/5.30M [00:00<00:00, 280MB/s]
# Ultralytics YOLOv8.1.42 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !scp -r /content/runs '/content/gdrive/My Drive/data'
