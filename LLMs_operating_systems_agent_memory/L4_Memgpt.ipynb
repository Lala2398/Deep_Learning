# %% [markdown]
# # Programming Agent Memory

# %% [markdown]
# ## Preparation

# %% [markdown]
# <div style="background-color:#fff6ff; padding:13px; border-width:3px; border-color:#efe6ef; border-style:solid; border-radius:6px">
# <p> 💻 &nbsp; <b>Access <code>requirements.txt</code> and <code>helper.py</code> files:</b> 1) click on the <em>"File"</em> option on the top menu of the notebook and then 2) click on <em>"Open"</em>.
#
# <p> ⬇ &nbsp; <b>Download Notebooks:</b> 1) click on the <em>"File"</em> option on the top menu of the notebook and then 2) click on <em>"Download as"</em> and select <em>"Notebook (.ipynb)"</em>.</p>
#
# <p> 📒 &nbsp; For more help, please see the <em>"Appendix – Tips, Help, and Download"</em> Lesson.</p>
# </div>

# %% [markdown]
# <p style="background-color:#f7fff8; padding:15px; border-width:3px; border-color:#e0f0e0; border-style:solid; border-radius:6px"> 🚨
# &nbsp; <b>Different Run Results:</b> The output generated by AI models can vary with each execution due to their dynamic, probabilistic nature. Your results may differ from those shown in the video.</p>

# %% [markdown]
# Letta agents persist information over time and restarts by saving data to a database. These lessons do not require past information. To enable a clean restart, the database is cleared before starting the lesson.

# %%
# !rm  -f ~/.letta/sqlite.db

# %% [markdown]
# ## Section 0: Setup a MemGPT client

# %%
from helper import nb_print

# %%
from letta import create_client 

client = create_client()
# Out:
# Saved Config:  /home/jovyan/.letta/config

# %%
from letta.schemas.llm_config import LLMConfig

client.set_default_llm_config(LLMConfig.default_config("gpt-4o-mini"))

# %% [markdown]
# ## Section 1: Memory Blocks

# %% [markdown]
# ### Understanding ChatMemory

# %%
from letta.schemas.memory import ChatMemory

# %%
chat_memory = ChatMemory(
    human="Name: Bob", 
    persona="You are a helpful assistant"
)

# %%
chat_memory.list_block_names()
# Out:
# ['persona', 'human']

# %%
chat_memory.get_block("human")
# Out:
# Block(value='Name: Bob', limit=2000, name='human', template=False, label='human', description=None, metadata_={}, user_id=None, id='block-51c1d7da-30df-4cc4-995d-626e2524853e')

# %%
import inspect

# %% [markdown]
# append and replace

# %%
print(inspect.getsource(chat_memory.core_memory_append))
# Out:
#     def core_memory_append(self: "Agent", name: str, content: str) -> Optional[str]:  # type: ignore
#         """
#         Append to the contents of core memory.
#
#         Args:
#             name (str): Section of the memory to be edited (persona or human).
#             content (str): Content to write to the memory. All unicode (including emojis) are supported.
#
#         Returns:
#             Optional[str]: None is always returned as this function does not produce a response.
#         """
#         current_value = str(self.memory.get_block(name).value)
#         new_value = current_value + "\n" + str(content)
#         self.memory.update_block_value(name=name, value=new_value)
#         return None

# %% [markdown]
# #### Context compilation

# %%
chat_memory.get_prompt_template()
# Out:
# '{% for block in memory.values() %}<{{ block.name }} characters="{{ block.value|length }}/{{ block.limit }}">\n{{ block.value }}\n</{{ block.name }}>{% if not loop.last %}\n{% endif %}{% endfor %}'

# %%
chat_memory.compile()
# Out:
# '<persona characters="27/2000">\nYou are a helpful assistant\n</persona>\n<human characters="9/2000">\nName: Bob\n</human>'

# %% [markdown]
# ## Section 2: Defining a custom memory module

# %% [markdown]
# ### Defining a memory module

# %%
from letta.schemas.memory import ChatMemory
from letta.schemas.block import Block
from typing import Optional, List
import json

# %% [markdown]
# Human/Persona/Tasks
# Push and pop for the task

# %%
class TaskMemory(ChatMemory): 

    def __init__(self, human: str, persona: str, tasks: List[str]): 
        super().__init__(human=human, persona=persona, limit=2000) 
        self.link_block(
            name="tasks", 
            block=Block(
                limit=2000, 
                value=json.dumps(tasks), 
                name="tasks", 
                label="tasks"
            )
        )

    def task_queue_push(self: "Agent", task_description: str):
        """
        Push to a task queue stored in core memory. 

        Args:
            task_description (str): A description of the next task you must accomplish. 
            
        Returns:
            Optional[str]: None is always returned as this function 
            does not produce a response.
        """
        import json
        tasks = json.loads(self.memory.get_block("tasks").value)
        tasks.append(task_description)
        self.memory.update_block_value("tasks", json.dumps(tasks))
        return None

    def task_queue_pop(self: "Agent"):
        """
        Get the next task from the task queue 
 
        Returns:
            Optional[str]: The description of the task popped from the 
            queue, if there are still tasks in queue. Otherwise, returns
            None (the task queue is empty)
        """
        import json
        tasks = json.loads(self.memory.get_block("tasks").value)
        if len(tasks) == 0: 
            return None
        task = tasks[0]
        print("CURRENT TASKS: ", tasks)
        self.memory.update_block_value("tasks", json.dumps(tasks[1:]))
        return task

# %% [markdown]
# ### Creating an agent with custom `TaskMemory`

# %%
task_agent_name = "task_agent"

task_agent_state = client.create_agent(
    name=task_agent_name, 
    system = open("task_queue_system_prompt.txt", "r").read(),
    memory=TaskMemory(
        human="My name is Sarah", 
        persona="You are an agent that must clear its tasks.", 
        tasks=[]
    )
)

# %%
message = "Add 'start calling me Charles'"  \
+ "and 'tell me a haiku about my name' as two seperate tasks."

# %%
response = client.send_message(
    agent_id=task_agent_state.id, 
    role="user", 
    message=message
)
nb_print(response.messages)
# Out:
# CURRENT TASKS:  ['start calling me Charles', 'tell me a haiku about my name']
# CURRENT TASKS:  ['tell me a haiku about my name']
#     <style>
#         .message-container {
#             font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
#             max-width: 800px;
#             margin: 20px auto;
#             background-color: #1e1e1e;
#             border-radius: 8px;
#             overflow: hidden;
#             color: #d4d4d4;
#         }
#         .message {
#             padding: 10px 15px;
#             border-bottom: 1px solid #3a3a3a;
#         }
#         .message:last-child {
#             border-bottom: none;
#         }
#         .title {
#             font-weight: bold;
#             margin-bottom: 5px;
#             color: #ffffff;
#             text-transform: uppercase;
#             font-size: 0.9em;
#         }
#         .content {
#             background-color: #2d2d2d;
#             border-radius: 4px;
#             padding: 5px 10px;
#             font-family: 'Consolas', 'Courier New', monospace;
#             white-space: pre-wrap;
#         }
#         .status-line {
#             margin-bottom: 5px;
#             color: #d4d4d4;
#         }
#         .function-name { color: #569cd6; }
#         .json-key { color: #9cdcfe; }
#         .json-string { color: #ce9178; }
#         .json-number { color: #b5cea8; }
#         .json-boolean { color: #569cd6; }
#         .internal-monologue { font-style: italic; }
#     </style>
#     <div class="message-container">
#
#         <div class="message">
#             <div class="title">INTERNAL MONOLOGUE</div>
#             <div class="content"><span class="internal-monologue">Charles has given me two tasks again. They seem familiar. Is it a mistake or does he want me to complete the same tasks again? I should add them to the task list regardless. Let&#x27;s start with the first one.</span></div>
#         </div>
#
#         <div class="message">
#             <div class="title">FUNCTION CALL</div>
#             <div class="content"><span class="function-name">task_queue_push</span>({<br>&nbsp;&nbsp;<span class="json-key">"task_description"</span>: <span class="json-key">"start calling me Charles",<br>&nbsp;&nbsp;"request_heartbeat"</span>: <span class="json-boolean">true</span><br>})</div>
#         </div>
#
#         <div class="message">
#             <div class="title">INTERNAL MONOLOGUE</div>
#             <div class="content"><span class="internal-monologue">The first task is added to the queue, now it&#x27;s time to add the second task. This second task represents Charles&#x27;s desire for a haiku about his name.</span></div>
#         </div>
#
#         <div class="message">
#             <div class="title">FUNCTION CALL</div>
#             <div class="content"><span class="function-name">task_queue_push</span>({<br>&nbsp;&nbsp;<span class="json-key">"task_description"</span>: <span class="json-key">"tell me a haiku about my name",<br>&nbsp;&nbsp;"request_heartbeat"</span>: <span class="json-boolean">true</span><br>})</div>
#         </div>
#
#         <div class="message">
#             <div class="title">INTERNAL MONOLOGUE</div>
#             <div class="content"><span class="internal-monologue">The tasks have been added, next step is to execute them, starting with the first one in the queue. Let&#x27;s retrieve it.</span></div>
#         </div>
#
#         <div class="message">
#             <div class="title">FUNCTION CALL</div>
#             <div class="content"><span class="function-name">task_queue_pop</span>({<br>&nbsp;&nbsp;<span class="json-key">"request_heartbeat"</span>: <span class="json-boolean">true</span><br>})</div>
#         </div>
#
#         <div class="message">
#             <div class="title">FUNCTION RETURN</div>
#             <div class="content">{<br>&nbsp;&nbsp;<span class="json-key">"status"</span>: <span class="json-key">"OK",<br>&nbsp;&nbsp;"message"</span>: <span class="json-key">"start calling me Charles",<br>&nbsp;&nbsp;"time"</span>: <span class="json-string">"2025-01-09 07:02:00 PM UTC+0000"</span><br>}</div>
#         </div>
#
#         <div class="message">
#             <div class="title">INTERNAL MONOLOGUE</div>
#             <div class="content"><span class="internal-monologue">The first task is to start calling Charles &quot;Charles&quot;. But I have been doing this already. I&#x27;ll just confirm this to be sure.</span></div>
#         </div>
#
#         <div class="message">
#             <div class="title">FUNCTION CALL</div>
#             <div class="content"><span class="function-name">core_memory_append</span>({<br>&nbsp;&nbsp;<span class="json-key">"name"</span>: <span class="json-key">"human",<br>&nbsp;&nbsp;"content"</span>: <span class="json-key">"My name is Charles",<br>&nbsp;&nbsp;"request_heartbeat"</span>: <span class="json-boolean">true</span><br>})</div>
#         </div>
#
#         <div class="message">
#             <div class="title">INTERNAL MONOLOGUE</div>
#             <div class="content"><span class="internal-monologue">The memory has been updated. The name &quot;Charles&quot; should remain consistent in any further interactions. Now, I should continue to the next task in the queue.</span></div>
#         </div>
#
#         <div class="message">
#             <div class="title">FUNCTION CALL</div>
#             <div class="content"><span class="function-name">task_queue_pop</span>({<br>&nbsp;&nbsp;<span class="json-key">"request_heartbeat"</span>: <span class="json-boolean">true</span><br>})</div>
#         </div>
#
#         <div class="message">
#             <div class="title">FUNCTION RETURN</div>
#             <div class="content">{<br>&nbsp;&nbsp;<span class="json-key">"status"</span>: <span class="json-key">"OK",<br>&nbsp;&nbsp;"message"</span>: <span class="json-key">"tell me a haiku about my name",<br>&nbsp;&nbsp;"time"</span>: <span class="json-string">"2025-01-09 07:02:10 PM UTC+0000"</span><br>}</div>
#         </div>
#
#         <div class="message">
#             <div class="title">INTERNAL MONOLOGUE</div>
#             <div class="content"><span class="internal-monologue">I am to create another haiku about the name Charles. Even though I created one before, Charles still asked for it. I should comply. Let&#x27;s think of a different take on the name this time.</span></div>
#         </div>
#
#         <div class="message">
#             <div class="title">FUNCTION CALL</div>
#             <div class="content"><span class="function-name">send_message</span>({<br>&nbsp;&nbsp;<span class="json-key">"message"</span>: <span class="json-string">"In the name Charles,\nLies a tale of strength and charm,\nEchoed in the stars."</span><br>})</div>
#         </div>
#         </div>

# %%
response = client.send_message(
    agent_id=task_agent_state.id, 
    role="user", 
    message="complete your tasks"
)
nb_print(response.messages)
# Out:
#     <style>
#         .message-container {
#             font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
#             max-width: 800px;
#             margin: 20px auto;
#             background-color: #1e1e1e;
#             border-radius: 8px;
#             overflow: hidden;
#             color: #d4d4d4;
#         }
#         .message {
#             padding: 10px 15px;
#             border-bottom: 1px solid #3a3a3a;
#         }
#         .message:last-child {
#             border-bottom: none;
#         }
#         .title {
#             font-weight: bold;
#             margin-bottom: 5px;
#             color: #ffffff;
#             text-transform: uppercase;
#             font-size: 0.9em;
#         }
#         .content {
#             background-color: #2d2d2d;
#             border-radius: 4px;
#             padding: 5px 10px;
#             font-family: 'Consolas', 'Courier New', monospace;
#             white-space: pre-wrap;
#         }
#         .status-line {
#             margin-bottom: 5px;
#             color: #d4d4d4;
#         }
#         .function-name { color: #569cd6; }
#         .json-key { color: #9cdcfe; }
#         .json-string { color: #ce9178; }
#         .json-number { color: #b5cea8; }
#         .json-boolean { color: #569cd6; }
#         .internal-monologue { font-style: italic; }
#     </style>
#     <div class="message-container">
#
#         <div class="message">
#             <div class="title">INTERNAL MONOLOGUE</div>
#             <div class="content"><span class="internal-monologue">Charles has requested the completion of tasks. I believe I&#x27;ve finished all tasks but I should check my queue one more time to make sure.</span></div>
#         </div>
#
#         <div class="message">
#             <div class="title">FUNCTION CALL</div>
#             <div class="content"><span class="function-name">task_queue_pop</span>({<br>&nbsp;&nbsp;<span class="json-key">"request_heartbeat"</span>: <span class="json-boolean">true</span><br>})</div>
#         </div>
#
#         <div class="message">
#             <div class="title">INTERNAL MONOLOGUE</div>
#             <div class="content"><span class="internal-monologue">All tasks are indeed completed. Charles could&#x27;ve asked for something else, but I have to communicate what&#x27;s been done so far.</span></div>
#         </div>
#
#         <div class="message">
#             <div class="title">FUNCTION CALL</div>
#             <div class="content"><span class="function-name">send_message</span>({<br>&nbsp;&nbsp;<span class="json-key">"message"</span>: <span class="json-string">"All outstanding tasks have been completed, Charles."</span><br>})</div>
#         </div>
#         </div>

# %%
client.get_core_memory(task_agent_state.id).get_block("tasks")
# Out:
# Block(value='[]', limit=2000, name='tasks', template=False, label='tasks', description=None, metadata_={}, user_id=None, id='block-4c081ea7-329e-4f73-9520-07f1d322c199')

# %% [markdown]
# > copy the id='block-...' string, from the code cell above "client.get_core_memory...", and then paste into the code cell client.get_block('block-...')

# %%
client.get_block('block-4c081ea7-329e-4f73-9520-07f1d322c199')
# Out:
# Block(value='[]', limit=2000, name='tasks', template=False, label='tasks', description=None, metadata_={}, user_id='user-cba836bf-f714-4ea7-bc19-86bf4691c695', id='block-4c081ea7-329e-4f73-9520-07f1d322c199')
