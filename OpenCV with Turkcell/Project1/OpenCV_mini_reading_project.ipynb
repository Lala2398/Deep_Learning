# %%
# !pip install opencv-python
# Out:
# ...
#   Obtaining dependency information for opencv-python from https://files.pythonhosted.org/packages/3f/a4/d2537f47fd7fcfba966bd806e3ec18e7ee1681056d4b0a9c8d983983e4d5/opencv_python-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 MB 4.6 MB/s eta 0:00:00m eta 0:00:010:00:010m
# ...

# %%
import cv2 as cv

# %%
path = "/home/lala/Downloads/1436c485a77a8a6f66b24b6d7c4da63c.png"

# %%
img=cv.imread(path)
#or you didn`t write png name your path you need to use like that form
# img=cv.imread(path+"png.name")

# %%
type(img)
# Out:
# numpy.ndarray

# %% [markdown]
# NamedWindow

# %%
cv.namedWindow("opencv_test",cv.WINDOW_AUTOSIZE) #original version
# Out:
# QObject::moveToThread: Current thread (0xf8cdf0) is not the object's thread (0x1d1bc10).
# Cannot move to target thread (0xf8cdf0)
#
# QObject::moveToThread: Current thread (0xf8cdf0) is not the object's thread (0x1d1bc10).
# Cannot move to target thread (0xf8cdf0)
#
# QObject::moveToThread: Current thread (0xf8cdf0) is not the object's thread (0x1d1bc10).
# Cannot move to target thread (0xf8cdf0)
#
# QObject::moveToThread: Current thread (0xf8cdf0) is not the object's thread (0x1d1bc10).
# Cannot move to target thread (0xf8cdf0)
#
# QObject::moveToThread: Current thread (0xf8cdf0) is not the object's thread (0x1d1bc10).
# Cannot move to target thread (0xf8cdf0)
#
# QObject::moveToThread: Current thread (0xf8cdf0) is not the object's thread (0x1d1bc10).
# Cannot move to target thread (0xf8cdf0)
#
# QObject::moveToThread: Current thread (0xf8cdf0) is not the object's thread (0x1d1bc10).
# Cannot move to target thread (0xf8cdf0)
#
# ...

# %% [markdown]
# imshow

# %%
cv.imshow("opencv_test",img)

# %%
#if we use 0 our window will be open at console. 
# We must write positive numbers at that code. 
#CTRL + C for escape 
cv.waitKey(1)
# Out:
# -1

# %%
#Closing all windows 
cv.destroyAllWindows()
